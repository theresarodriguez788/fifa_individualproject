# %%
#IMPORT DATA

# %%
import numpy as np
import pandas as pd

# %%
#import "players 20"

df = pd.read_csv("../data/players_20.csv")
print("Players 20")
display(df)
# Out:
# Players 20
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 18478     252568  https://sofifa.com/player/252568/mohammed-saga...
# 18479     252883  https://sofifa.com/player/252883/hector-kypria...
# 18480     252890  https://sofifa.com/player/252890/brandon-mcphe...
# 18481     252891  https://sofifa.com/player/252891/joseph-hope/2...
# 18482     252893  https://sofifa.com/player/252893/cameron-paint...
#
#               short_name                            long_name  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
#Null Value in each column "players 20"

df.isna().any()
# Out:
# sofifa_id           False
# player_url          False
# short_name          False
# long_name           False
# player_positions    False
#                     ...
# player_face_url     False
# club_logo_url        True
# club_flag_url        True
# nation_logo_url      True
# nation_flag_url     False
# Length: 110, dtype: bool

# %%
#Number of Null Values per column "players 20"

df.isna().sum()
# Out:
# sofifa_id               0
# player_url              0
# short_name              0
# long_name               0
# player_positions        0
#                     ...
# player_face_url         0
# club_logo_url         240
# club_flag_url         240
# nation_logo_url     17356
# nation_flag_url         0
# Length: 110, dtype: int64

# %%
# List of "Players 20" Columns 

list(df.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'player_positions',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'club_team_id',
#  'club_name',
#  'league_name',
#  'league_level',
#  'club_position',
#  'club_jersey_number',
#  'club_loaned_from',
#  'club_joined',
#  'club_contract_valid_until',
#  'nationality_id',
#  'nationality_name',
#  'nation_team_id',
#  'nation_position',
#  'nation_jersey_number',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'international_reputation',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'player_traits',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
# ...

# %%
df.dtypes
# Out:
# sofifa_id            int64
# player_url          object
# short_name          object
# long_name           object
# player_positions    object
#                      ...
# player_face_url     object
# club_logo_url       object
# club_flag_url       object
# nation_logo_url     object
# nation_flag_url     object
# Length: 110, dtype: object

# %%
#import "players 21"

df1 = pd.read_csv("../data/players_21.csv")
print("Players 21")
df1.head()
# Out:
# Players 21
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     188545  https://sofifa.com/player/188545/robert-lewand...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 2     R. Lewandowski                   Robert Lewandowski               ST
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CAM, CM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
#Null Value in each column "players 21"

df1.isna().any()
# Out:
# sofifa_id           False
# player_url          False
# short_name          False
# long_name           False
# player_positions    False
#                     ...
# player_face_url     False
# club_logo_url        True
# club_flag_url        True
# nation_logo_url      True
# nation_flag_url     False
# Length: 110, dtype: bool

# %%
#Number of Null Values per column "players 21"

df1.isna().sum()
# Out:
# sofifa_id               0
# player_url              0
# short_name              0
# long_name               0
# player_positions        0
#                     ...
# player_face_url         0
# club_logo_url         225
# club_flag_url         225
# nation_logo_url     17817
# nation_flag_url         0
# Length: 110, dtype: int64

# %%
# List of "Players 21" Columns 

list(df1.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'player_positions',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'club_team_id',
#  'club_name',
#  'league_name',
#  'league_level',
#  'club_position',
#  'club_jersey_number',
#  'club_loaned_from',
#  'club_joined',
#  'club_contract_valid_until',
#  'nationality_id',
#  'nationality_name',
#  'nation_team_id',
#  'nation_position',
#  'nation_jersey_number',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'international_reputation',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'player_traits',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
# ...

# %%
#Number of Null Values per column "players 21"

df1.isna().sum()
# Out:
# sofifa_id               0
# player_url              0
# short_name              0
# long_name               0
# player_positions        0
#                     ...
# player_face_url         0
# club_logo_url         225
# club_flag_url         225
# nation_logo_url     17817
# nation_flag_url         0
# Length: 110, dtype: int64

# %%
#import "players 22"

df2= pd.read_csv("../data/players_22.csv")
print("Players 22")
df2.head()
# Out:
# Players 22
# /var/folders/rc/zvv8g8zs7_d3j3t90ky433zw0000gn/T/ipykernel_70826/2518021350.py:3: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2= pd.read_csv("../data/players_22.csv")
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# ...

# %%
#Null Value in each column "players 22"

df1.isna().any()
# Out:
# sofifa_id           False
# player_url          False
# short_name          False
# long_name           False
# player_positions    False
#                     ...
# player_face_url     False
# club_logo_url        True
# club_flag_url        True
# nation_logo_url      True
# nation_flag_url     False
# Length: 110, dtype: bool

# %%
#Number of Null Values per column "players 22"

df2.isna().sum()
# Out:
# sofifa_id               0
# player_url              0
# short_name              0
# long_name               0
# player_positions        0
#                     ...
# player_face_url         0
# club_logo_url          61
# club_flag_url          61
# nation_logo_url     18480
# nation_flag_url         0
# Length: 110, dtype: int64

# %%
# List of "Players 22" Columns 

list(df2.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'player_positions',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'club_team_id',
#  'club_name',
#  'league_name',
#  'league_level',
#  'club_position',
#  'club_jersey_number',
#  'club_loaned_from',
#  'club_joined',
#  'club_contract_valid_until',
#  'nationality_id',
#  'nationality_name',
#  'nation_team_id',
#  'nation_position',
#  'nation_jersey_number',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'international_reputation',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'player_traits',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
# ...

# %%
#PLAYERS 20 - DROPPING COLUMNS + LOOKING AT TOP 10 + LEAGUE + CHART

# %%
# "Players 20" Reduced Columns + Top 10 "overall"
columns_to_drop = ['sofifa_id', 'player_url', 'short_name', 'value_eur', 'wage_eur', 'club_team_id', 'club_jersey_number', 'club_loaned_from', 'club_joined', 'club_contract_valid_until', 'nationality_id', 'nation_team_id', 'nation_jersey_number', 'weak_foot', 'skill_moves', 'international_reputation', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'player_traits', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking_awareness', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url', 'club_flag_url', 'nation_logo_url', 'nation_flag_url']
df.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore')
top_10_overall_20 = df.nlargest(10, 'overall')
display("Players 20 - Top 10 Overall",top_10_overall)
# Out:
# 'Players 20 - Top 10 Overall'
#                              long_name player_positions  overall  potential  \
# 0       Lionel Andrés Messi Cuccittini       RW, ST, CF       93         93
# 1                   Robert Lewandowski               ST       92         92
# 2  Cristiano Ronaldo dos Santos Aveiro           ST, LW       91         91
# 3        Neymar da Silva Santos Júnior          LW, CAM       91         91
# 4                      Kevin De Bruyne          CM, CAM       91         91
# 5                            Jan Oblak               GK       91         93
# 6                 Kylian Mbappé Lottin           ST, LW       91         95
# 7                   Manuel Peter Neuer               GK       90         90
# 8                Marc-André ter Stegen               GK       90         92
# 9                           Harry Kane               ST       90         90
#
#    age         dob  height_cm  weight_kg            club_name  \
# ...

# %%
#20 - Overall - Chart

chart_df = pd.DataFrame(top_10_overall_20.groupby(['league_name']).size()).reset_index()
chart_df.columns=["league_name","number_of_players"]
chart_df.sort_values(by='number_of_players', ascending=False, inplace=True)
print("Top 10 Overall by League - 20")
chart_df
# Out:
# Top 10 Overall by League - 20
#               league_name  number_of_players
# 3  Spain Primera Division                  5
# 0  English Premier League                  3
# 1          French Ligue 1                  1
# 2         Italian Serie A                  1

# %%
#20-Overall

import matplotlib.pyplot as plt

plt.subplots()
ax = sns.barplot(data=temp_df, x='number_of_players', y='league_name');
plt.savefig("../images/figure20_0.jpg", format="jpg")

print("Top 10 Overall by League - 20")
# Out:
# Top 10 Overall by League - 20

# %%
# "Players 20" Reduced Columns + Top 10 "potential"
columns_to_drop = ['sofifa_id', 'player_url', 'short_name', 'value_eur', 'wage_eur', 'club_team_id', 'club_jersey_number', 'club_loaned_from', 'club_joined', 'club_contract_valid_until', 'nationality_id', 'nation_team_id', 'nation_jersey_number', 'weak_foot', 'skill_moves', 'international_reputation', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'player_traits', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking_awareness', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url', 'club_flag_url', 'nation_logo_url', 'nation_flag_url']
df.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore')
top_10_potential_20 = df.nlargest(10, 'potential')
display("Players 20 - Top 10 Potential",top_10_potential_20)
# Out:
# 'Players 20 - Top 10 Potential'
#                                long_name player_positions  overall  potential  \
# 22                  Kylian Mbappé Lottin           ST, RW       89         95
# 0         Lionel Andrés Messi Cuccittini       RW, CF, ST       94         94
# 1    Cristiano Ronaldo dos Santos Aveiro           ST, LW       93         93
# 5                              Jan Oblak               GK       91         93
# 7                  Marc-André ter Stegen               GK       90         93
# 107                     Matthijs de Ligt               CB       85         93
# 565                  João Félix Sequeira           CF, ST       80         93
# 2          Neymar da Silva Santos Júnior          LW, CAM       92         92
# 39           Paulo Bruno Exequiel Dybala          CAM, RW       88         92
# 71                       Leroy Aziz Sané               LW       86         92
#
#      age         dob  height_cm  weight_kg            club_name  \
# ...

# %%
#20 - POTENTIAL - Chart

chart_df = pd.DataFrame(top_10_potential_20.groupby(['league_name']).size()).reset_index()
chart_df.columns=["league_name","number_of_players"]
chart_df.sort_values(by='number_of_players', ascending=False, inplace=True)
print("Top 10 Potential by League - 20")
chart_df
# Out:
# Top 10 Potential by League - 20
#               league_name  number_of_players
# 3  Spain Primera Division                  4
# 2         Italian Serie A                  3
# 1          French Ligue 1                  2
# 0  English Premier League                  1

# %%
#20-Potential 

import matplotlib.pyplot as plt

plt.subplots()
ax = sns.barplot(data=temp_dfa, x='number_of_players', y='league_name');
plt.savefig("../images/figure20_p.jpg", format="jpg")

print("Top 10 Potential Leagues - 20")
# Out:
# Top 10 Potential Leagues - 20

# %%
#PLAYERS 21 - DROPPING COLUMNS + LOOKING AT TOP 10 + LEAGUE + CHART

# %%
# "Players 21" Dropping Columns + Top 10 Overall
columns_to_drop = ['sofifa_id', 'player_url', 'short_name', 'value_eur', 'wage_eur', 'club_team_id', 'club_jersey_number', 'club_loaned_from', 'club_joined', 'club_contract_valid_until', 'nationality_id', 'nation_team_id', 'nation_jersey_number', 'weak_foot', 'skill_moves', 'international_reputation', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'player_traits', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking_awareness', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url', 'club_flag_url', 'nation_logo_url', 'nation_flag_url']
df1.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore')
top_10_overall_21 = df1.nlargest(10, 'overall')
display("Players 21 - Top 10 Overall",top_10_overall_21)
# Out:
# 'Players 21 - Top 10 Overall'
#                              long_name player_positions  overall  potential  \
# 0       Lionel Andrés Messi Cuccittini       RW, ST, CF       93         93
# 1  Cristiano Ronaldo dos Santos Aveiro           ST, LW       92         92
# 2                   Robert Lewandowski               ST       91         91
# 3        Neymar da Silva Santos Júnior          LW, CAM       91         91
# 4                      Kevin De Bruyne          CAM, CM       91         91
# 5                            Jan Oblak               GK       91         93
# 6                Marc-André ter Stegen               GK       90         93
# 7                      Virgil van Dijk               CB       90         91
# 8                           Sadio Mané               LW       90         90
# 9                  Mohamed Salah Ghaly               RW       90         90
#
#    age         dob  height_cm  weight_kg            club_name  \
# ...

# %%
#21-Overall 

temp_df1 = pd.DataFrame(top_10_overall_21.groupby(['league_name']).size()).reset_index()
temp_df1.columns=["league_name","number_of_players"]
temp_df1.sort_values(by='number_of_players', ascending=False, inplace=True)
print("Top 10 Overall by League")
temp_df1
# Out:
# Top 10 Overall by League
#               league_name  number_of_players
# 0  English Premier League                  4
# 4  Spain Primera Division                  3
# 1          French Ligue 1                  1
# 2    German 1. Bundesliga                  1
# 3         Italian Serie A                  1

# %%
#21-Overall 

import matplotlib.pyplot as plt

plt.subplots()
ax = sns.barplot(data=temp_df1, x='number_of_players', y='league_name');
plt.savefig("../images/figure21_o.jpg", format="jpg")

print("Top 10 Overall Leagues - 21")
# Out:
# Top 10 Overall Leagues - 21

# %%
# "Players 21" Dropping Columns + Top 10 Potential
columns_to_drop = ['sofifa_id', 'player_url', 'short_name', 'value_eur', 'wage_eur', 'club_team_id', 'club_jersey_number', 'club_loaned_from', 'club_joined', 'club_contract_valid_until', 'nationality_id', 'nation_team_id', 'nation_jersey_number', 'weak_foot', 'skill_moves', 'international_reputation', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'player_traits', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking_awareness', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url', 'club_flag_url', 'nation_logo_url', 'nation_flag_url']
df1.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore')
top_10_potential_21 = df1.nlargest(10, 'potential')
display("Players 21 - Top 10 Potential",top_10_potential_21)
# Out:
# 'Players 21 - Top 10 Potential'
#                                    long_name player_positions  overall  \
# 11                      Kylian Mbappé Lottin       ST, LW, RW       90
# 0             Lionel Andrés Messi Cuccittini       RW, ST, CF       93
# 5                                  Jan Oblak               GK       91
# 6                      Marc-André ter Stegen               GK       90
# 47                              Jadon Sancho      RM, LM, CAM       87
# 98                         Kai Lukas Havertz      CAM, RM, CF       85
# 364                      João Félix Sequeira           CF, ST       81
# 488  Vinícius José Paixão de Oliveira Júnior               LW       80
# 1        Cristiano Ronaldo dos Santos Aveiro           ST, LW       92
# 46                    Trent Alexander-Arnold               RB       87
#
#      potential  age         dob  height_cm  weight_kg            club_name  \
# 11          95   21  1998-12-20        178         73  Paris Saint-Germain
# ...

# %%
#21-Potential 

temp_df1a = pd.DataFrame(top_10_potential_21.groupby(['league_name']).size()).reset_index()
temp_df1a.columns=["league_name","number_of_players"]
temp_df1a.sort_values(by='number_of_players', ascending=False, inplace=True)
print("Top 10 Potential by League")
temp_df1a
# Out:
# Top 10 Potential by League
#               league_name  number_of_players
# 4  Spain Primera Division                  5
# 0  English Premier League                  2
# 1          French Ligue 1                  1
# 2    German 1. Bundesliga                  1
# 3         Italian Serie A                  1

# %%
#21-Potential 

import matplotlib.pyplot as plt

plt.subplots()
ax = sns.barplot(data=temp_df1a, x='number_of_players', y='league_name');
plt.savefig("../images/figure21_p.jpg", format="jpg")

print("Top 10 Potential - Leagues - 21")
# Out:
# Top 10 Potential - Leagues - 21

# %%
#PLAYERS 22 - DROPPING COLUMNS + LOOKING AT TOP 10 + LEAGUE + CHART

# %%
# Players 22" Reduced Columns + Top 10 Overall 
columns_to_drop = ['sofifa_id', 'player_url', 'short_name', 'value_eur', 'wage_eur', 'club_team_id', 'club_jersey_number', 'club_loaned_from', 'club_joined', 'club_contract_valid_until', 'nationality_id', 'nation_team_id', 'nation_jersey_number', 'weak_foot', 'skill_moves', 'international_reputation', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'player_traits', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking_awareness', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url', 'club_flag_url', 'nation_logo_url', 'nation_flag_url']
df2.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore')
top_10_overall_22 = df2.nlargest(10, 'overall')
display("Players 22 - Top 10 Overall",top_10_overall_22)
# Out:
# 'Players 22 - Top 10 Overall'
#                              long_name player_positions  overall  potential  \
# 0       Lionel Andrés Messi Cuccittini       RW, ST, CF       93         93
# 1                   Robert Lewandowski               ST       92         92
# 2  Cristiano Ronaldo dos Santos Aveiro           ST, LW       91         91
# 3        Neymar da Silva Santos Júnior          LW, CAM       91         91
# 4                      Kevin De Bruyne          CM, CAM       91         91
# 5                            Jan Oblak               GK       91         93
# 6                 Kylian Mbappé Lottin           ST, LW       91         95
# 7                   Manuel Peter Neuer               GK       90         90
# 8                Marc-André ter Stegen               GK       90         92
# 9                           Harry Kane               ST       90         90
#
#    age         dob  height_cm  weight_kg            club_name  \
# ...

# %%
#22-Overall 

temp_df2 = pd.DataFrame(top_10_overall_22.groupby(['league_name']).size()).reset_index()
temp_df2.columns=["league_name","number_of_players"]
temp_df2.sort_values(by='number_of_players', ascending=False, inplace=True)
print("Top 10 Overall by League")
temp_df2
# Out:
# Top 10 Overall by League
#               league_name  number_of_players
# 0  English Premier League                  3
# 1          French Ligue 1                  3
# 2    German 1. Bundesliga                  2
# 3  Spain Primera Division                  2

# %%
#22-Overall 

import matplotlib.pyplot as plt

plt.subplots()
ax = sns.barplot(data=temp_df1, x='number_of_players', y='league_name');
plt.savefig("../images/figure22_O.jpg", format="jpg")

print("Top 10 Overall Leagues - 22")
# Out:
# Top 10 Overall Leagues - 22

# %%
# Players 22" Reduced Columns + Top 10 Potential 
columns_to_drop = ['sofifa_id', 'player_url', 'short_name', 'value_eur', 'wage_eur', 'club_team_id', 'club_jersey_number', 'club_loaned_from', 'club_joined', 'club_contract_valid_until', 'nationality_id', 'nation_team_id', 'nation_jersey_number', 'weak_foot', 'skill_moves', 'international_reputation', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'player_traits', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking_awareness', 'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url', 'club_flag_url', 'nation_logo_url', 'nation_flag_url']
df2.drop(columns=columns_to_drop, axis=1, inplace=True, errors='ignore')
top_10_potential_22 = df2.nlargest(10, 'potential')
display("Players 22 - Top 10 Potential",top_10_potential_22)
# Out:
# 'Players 22 - Top 10 Potential'
#                           long_name player_positions  overall  potential  age  \
# 6              Kylian Mbappé Lottin           ST, LW       91         95   22
# 0    Lionel Andrés Messi Cuccittini       RW, ST, CF       93         93   34
# 5                         Jan Oblak               GK       91         93   28
# 21             Gianluigi Donnarumma               GK       89         93   22
# 29             Erling Braut Haaland               ST       88         93   20
# 1                Robert Lewandowski               ST       92         92   32
# 8             Marc-André ter Stegen               GK       90         92   29
# 43                  Frenkie de Jong      CM, CDM, CB       87         92   24
# 44           Trent Alexander-Arnold               RB       87         92   22
# 138               Kai Lukas Havertz      CAM, CF, CM       84         92   22
#
#             dob  height_cm  weight_kg            club_name  \
# ...

# %%
#22-Potential 

temp_df2a = pd.DataFrame(top_10_potential_22.groupby(['league_name']).size()).reset_index()
temp_df2a.columns=["league_name","number_of_players"]
temp_df2a.sort_values(by='number_of_players', ascending=False, inplace=True)
print("Top 10 Potential by League")
temp_df2a
# Out:
# Top 10 Potential by League
#               league_name  number_of_players
# 1          French Ligue 1                  3
# 3  Spain Primera Division                  3
# 0  English Premier League                  2
# 2    German 1. Bundesliga                  2

# %%
#22-Potential 

import matplotlib.pyplot as plt

plt.subplots()
ax = sns.barplot(data=temp_df2a, x='number_of_players', y='league_name');
plt.savefig("../images/figure22_p.jpg", format="jpg")

print("Top 10 Potential - Leagues - 22")
# Out:
# Top 10 Potential - Leagues - 22

# %%
# AGE VERSUS RANKING - 21

# %%
temp_df21 = pd.DataFrame(top_10_overall_21.groupby(['age']).size()).reset_index()
temp_df21.columns=["age","number_of_players"]
temp_df21.sort_values(by='age', ascending=True, inplace=True) 
print("Top 10 Overall by Age")
display(temp_df21)
# Out:
# Top 10 Overall by Age
#    age  number_of_players
# 0   27                  1
# 1   28                  5
# 2   29                  1
# 3   31                  1
# 4   33                  1
# 5   35                  1

# %%
#22 Overall by Age Graph

import matplotlib.pyplot as plt

plt.subplots()
ax = sns.barplot(data=temp_df21, x='age', y='number_of_players');
plt.savefig("../images/figure22_p.jpg", format="jpg")

print("2021 - Top 10 - by Age")
# Out:
# 2021 - Top 10 - by Age

# %%
# AGE VERSUS RANKING - 22

# %%
temp_df22 = pd.DataFrame(top_10_overall_22.groupby(['age']).size()).reset_index()
temp_df22.columns=["age","number_of_players"]
temp_df22.sort_values(by='age', ascending=True, inplace=True)
print("Top 10 Overall by Age")
display(temp_df22)
# Out:
# Top 10 Overall by Age
#    age  number_of_players
# 0   22                  1
# 1   27                  1
# 2   28                  1
# 3   29                  2
# 4   30                  1
# 5   32                  1
# 6   34                  1
# 7   35                  1
# 8   36                  1

# %%
#22 Overall by Age Graph

import matplotlib.pyplot as plt

plt.subplots()
ax = sns.barplot(data=temp_df22, x='age', y='number_of_players');
plt.savefig("../images/figure22_p.jpg", format="jpg")

print("2022 - Top 10 - by Age")
# Out:
# 2022 - Top 10 - by Age

# %%
#22-Potential 

import matplotlib.pyplot as plt

plt.line()
ax = sns.line(data=temp_df2a, x='number_of_players', y='league_name');
plt.savefig("../images/figure22_p.jpg", format="jpg")

print("Top 10 Potential - Leagues - 22")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[230], line 1
# ----> 1 from bokeh.plotting import figure, show, output_file
#       2 from bokeh.io import output_notebook
#       4 # Sample data
#       5 # Replace these with your actual data from temp_df22
#
# ModuleNotFoundError: No module named 'bokeh'

# %%
#!pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.thescore.com/fmf_ap/news/2525176"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Find all <h3> tags with the specified class name
player_names_tags = soup.find_all("h3")


results = [ ( player.get_text().split(".")[0], player.get_text().split(".")[1].strip()[:-3] ) for player in player_names_tags]

results_df = pd.DataFrame(results, columns=["Ranking", "Name"]).reset_index()
results_df.sort_values(by='index', ascending=False, inplace=True)
results_df['Year'] = 2022
results_df
# Out:
#    index Ranking                Name  Year
# 9      9       1        Lionel Messi  2022
# 8      8       2       Karim Benzema  2022
# 7      7       3       Kylian Mbappe  2022
# 6      6       4      Erling Haaland  2022
# 5      5       5     Kevin De Bruyne  2022
# 4      4       6     Vinicius Junior  2022
# 3      3       7  Robert Lewandowski  2022
# 2      2       8          Sadio Mane  2022
# 1      1       9         Rafael Leao  2022
# 0      0      10              Neymar  2022

# %%
results_df["Name"].unique()
# Out:
# array(['Lionel Messi', 'Karim Benzema', 'Kylian Mbappe', 'Erling Haaland',
#        'Kevin De Bruyne', 'Vinicius Junior', 'Robert Lewandowski',
#        'Sadio Mane', 'Rafael Leao', 'Neymar'], dtype=object)

# %%
#results_df["Name"].unique()
#top_10_overall_22['long_name'].unique()
# Out:
# array(['Lionel Andrés Messi Cuccittini', 'Robert Lewandowski',
#        'Cristiano Ronaldo dos Santos Aveiro',
#        'Neymar da Silva Santos Júnior', 'Kevin De Bruyne', 'Jan Oblak',
#        'Kylian Mbappé Lottin', 'Manuel Peter Neuer',
#        'Marc-André ter Stegen', 'Harry Kane'], dtype=object)

# %%
#mapping_dictionary = {'Lionel Andrés Messi Cuccittini':'Lionel Messi '}:
#top_10_overall_22['long_name'] = top_10_overall_22['long_name'].map(mapping_dictionary)

# %%
#pd.merge(top_10_overall_22, results_df, on_left="Ranking", on_right="index", how="inner")
